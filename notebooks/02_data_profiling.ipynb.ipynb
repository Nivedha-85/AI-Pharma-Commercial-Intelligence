# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# %%
df = pd.read_csv('/Users/nivedha/AI-Pharma-Commercial-Intelligence/data/raw/cms_partd_raw.csv')
# Out:
# /var/folders/9b/l9_w0nbs7qb65sxv54c5nxbw0000gp/T/ipykernel_67387/200492120.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/nivedha/AI-Pharma-Commercial-Intelligence/data/raw/cms_partd_raw.csv')

# %%
df.head()
# Out:
#    Prscrbr_NPI Prscrbr_Last_Org_Name Prscrbr_First_Name Prscrbr_City  \
# 0   1003000126             Enkeshafi            Ardalan     Bethesda
# 1   1003000126             Enkeshafi            Ardalan     Bethesda
# 2   1003000142                Khalil             Rashid       Toledo
# 3   1003000142                Khalil             Rashid       Toledo
# 4   1003000142                Khalil             Rashid       Toledo
#
#   Prscrbr_State_Abrvtn Prscrbr_State_FIPS       Prscrbr_Type Prscrbr_Type_Src  \
# 0                   MD                 24  Internal Medicine  Claim-Specialty
# 1                   MD                 24  Internal Medicine  Claim-Specialty
# 2                   OH                 39     Anesthesiology  Claim-Specialty
# 3                   OH                 39     Anesthesiology  Claim-Specialty
# 4                   OH                 39     Anesthesiology  Claim-Specialty
#
#                Brnd_Name                       Gnrc_Name  Tot_Clms  \
# ...

# %%
df.shape
# Out:
# (500000, 22)

# %%
rows, cols = df.shape
print(f"Rows ", {rows})
print(f"Columns", {cols})
# Out:
# Rows  {500000}
# Columns {22}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Prscrbr_NPI            500000 non-null  int64
#  1   Prscrbr_Last_Org_Name  500000 non-null  object
#  2   Prscrbr_First_Name     500000 non-null  object
#  3   Prscrbr_City           500000 non-null  object
#  4   Prscrbr_State_Abrvtn   500000 non-null  object
#  5   Prscrbr_State_FIPS     500000 non-null  object
#  6   Prscrbr_Type           500000 non-null  object
#  7   Prscrbr_Type_Src       500000 non-null  object
#  8   Brnd_Name              500000 non-null  object
#  9   Gnrc_Name              500000 non-null  object
#  10  Tot_Clms               500000 non-null  int64
#  11  Tot_30day_Fills        500000 non-null  float64
#  12  Tot_Day_Suply          500000 non-null  int64
#  13  Tot_Drug_Cst           500000 non-null  float64
# ...

# %%
missing = (
    df.isnull()
      .sum()
      .sort_values(ascending=False)
)

missing
# Out:
# GE65_Tot_Benes           439611
# GE65_Sprsn_Flag          275530
# Tot_Benes                271695
# GE65_Tot_Day_Suply       224470
# GE65_Tot_Drug_Cst        224470
# GE65_Tot_30day_Fills     224470
# GE65_Tot_Clms            224470
# GE65_Bene_Sprsn_Flag      60389
# Prscrbr_Last_Org_Name         0
# Tot_Drug_Cst                  0
# Tot_Day_Suply                 0
# Prscrbr_NPI                   0
# Tot_Clms                      0
# Gnrc_Name                     0
# Brnd_Name                     0
# Prscrbr_Type_Src              0
# Prscrbr_Type                  0
# Prscrbr_State_FIPS            0
# Prscrbr_State_Abrvtn          0
# Prscrbr_City                  0
# Prscrbr_First_Name            0
# Tot_30day_Fills               0
# dtype: int64

# %%
duplicates = df.duplicated().sum()

print(f"Duplicate rows: {duplicates}")
# Out:
# Duplicate rows: 0

# %%
print("Unique Providers   :", df["Prscrbr_NPI"].nunique())
print("Unique Drugs       :", df["Brnd_Name"].nunique())
print("Unique Cities      :", df["Prscrbr_City"].nunique())
print("Unique States      :", df["Prscrbr_State_Abrvtn"].nunique())
print("Unique Specialties :", df["Prscrbr_Type"].nunique())
# Out:
# Unique Providers   : 21025
# Unique Drugs       : 1982
# Unique Cities      : 3754
# Unique States      : 55
# Unique Specialties : 98
